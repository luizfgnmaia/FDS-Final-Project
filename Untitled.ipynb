# %%
import numpy as np
import pandas as pd
from selenium import webdriver # http://pythonclub.com.br/selenium-parte-1.html
from selenium.webdriver.firefox.options import Options # https://stackoverflow.com/questions/53134306/deprecationwarning-use-setter-for-headless-property-instead-of-set-headless-opt
import time # https://www.tutorialspoint.com/python/time_sleep
import re # https://www.w3schools.com/python/python_regex.asp

from get_hrefs import *

# %%
hrefs = get_hrefs(*["https://www.flashscore.com/football/bolivia/division-profesional/archive/"])
hrefs
# Out:
# ['/football/bolivia/division-profesional/',
#  '/football/bolivia/division-profesional-2018/',
#  '/football/bolivia/division-profesional-2016-2017/',
#  '/football/bolivia/division-profesional-2015-2016/',
#  '/football/bolivia/division-profesional-2014-2015/',
#  '/football/bolivia/division-profesional-2013-2014/',
#  '/football/bolivia/division-profesional-2012-2013/',
#  '/football/bolivia/division-profesional-2011-2012/',
#  '/football/bolivia/division-profesional-2011/',
#  '/football/bolivia/division-profesional-2010/',
#  '/football/bolivia/division-profesional-2009/',
#  '/football/bolivia/division-profesional-2008/',
#  '/football/bolivia/division-profesional-2007/',
#  '/football/bolivia/division-profesional-2006/',
#  '/football/bolivia/division-profesional-2005/',
#  '/football/bolivia/division-profesional-2004/',
#  '/football/bolivia/division-profesional-2003/',
#  '/football/bolivia/division-profesional-2002/',
#  '/football/bolivia/division-profesional-2001/',
#  '/football/bolivia/division-profesional-2000/']

# %%
lst_df = []

# Iniciando o Selenium
opt = Options() # https://datarebellion.com/blog/using-headless-firefox-with-selenium-in-python/
opt.headless = True
wd = webdriver.Firefox(executable_path = "./geckodriver.exe", options = opt)

for href in hrefs:

    # Indo até a página
    wd.get("https://www.flashscore.com" + href + "results/")

    # Clicando no mostrar mais até que não dê mais
    stop = False
    while stop == False:
        try:
            show_more = wd.find_element_by_css_selector(".event__more--static") 
            show_more.click()
            time.sleep(2)
        except:
            stop = True        

    new_page = wd.page_source

    # Coletando as linhas
    rows = []
    we = wd.find_elements_by_css_selector(".event__match--oneLine")
    for i in we:
        rows.append(i.text)

    # Coletando data da partida e nome do torneio
    we = wd.find_element_by_css_selector("div.teamHeader__text")
    year = we.text
    date = [row[0:5]+"."+year for row in rows]
    we = wd.find_element_by_css_selector("div.teamHeader__name")
    tournament = we.text

    # Separando as informações das linhas e preparando o output
    rows = [re.sub("\s\([A-Za-z]*\)", "", row) for row in rows] # Flamengo RJ (Bra) -> Flamengo RJ na Libertadores
    rows = [re.sub("\\nAwarded", "", row) for row in rows]
    rows = [re.sub("\((?=[^0-9])", "[", row) for row in rows]
    rows = [re.sub("(?<=[^0-9])\)", "]", row) for row in rows] 

    for i in range(len(rows)):
        last_par = rows[i].rfind("(")
        if last_par != -1 and rows[i][-1] == ")":
            rows[i] = rows[i][13:last_par-1].replace("\n", " ") 
        else:
            rows[i] = rows[i][13:].replace("\n", " ") 

    club_1 = []
    club_2 = []
    goals_1 = []
    goals_2 = []
    par_1 = []
    par_2 = []

    for i in range(len(rows)):
        if rows[i].find('(') != -1:
            parenthesis = re.search("\(.*\)", rows[i]).group()[1:-1]
            par_1.append(int(re.search(".*(?=-)", parenthesis).group()))
            par_2.append(int(re.search("(?<=-).*", parenthesis).group()))
        else:
            par_1.append(None)
            par_2.append(None)
        rows[i] = re.sub("\(.*\)", "", rows[i])
        placar_1 = re.search(".*(?=\s\s-)", rows[i])
        if placar_1 != None: # Se não tiver o resultado, não pegar
            placar_1 = placar_1.group()
            goals_1.append(int(placar_1[placar_1.rfind(" ")+1:]))
            club_1.append(placar_1[:placar_1.rfind(" ")])
        placar_2 = re.search("(?<=-\s\s).*", rows[i])
        if placar_2 != None:
            placar_2 = placar_2.group()
            goals_2.append(int(placar_2[:placar_2.find(" ")]))
            club_2.append(placar_2[placar_2.find(" "):].strip())

    # Salvando o data frame na lista
    df = pd.DataFrame(list(zip(date, club_1, goals_1, par_1, club_2, goals_2, par_2)), 
                       columns = ['date', 'club_1', 'goals_1', 'par_1', 'club_2', 'goals_2', 'par_2'])
    df['tournament'] = tournament
    lst_df.append(df)

# Unindo os data frames da lista
ret = pd.DataFrame(columns = df.columns)    
for i in range(len(lst_df)):
    ret = ret.append(lst_df[i], ignore_index = True)  
ret.replace(to_replace = [None], value = np.nan, inplace = True) # https://stackoverflow.com/questions/23743460/replace-none-with-nan-in-pandas-dataframe

wd.quit()

# %%
ret
# Out:
#             date             club_1  goals_1  par_1             club_2  \
# 0     30.08.2019       Always Ready        2    NaN           San Jose
# 1     29.08.2019        Real Potosi        1    NaN             Aurora
# 2     25.08.2019           Blooming        2    NaN       Always Ready
# 3     25.08.2019    Nacional Potosi        2    NaN  Oriente Petrolero
# 4     25.08.2019             Aurora        0    NaN            Bolivar
# 5     25.08.2019      The Strongest        2    NaN        Wilstermann
# 6     24.08.2019            Guabira        1    NaN         Destroyers
# 7     24.08.2019           San Jose        3    NaN        Real Potosi
# 8     24.08.2019         Sport Boys        1    NaN         Royal Pari
# 9     21.08.2019        Real Potosi        2    NaN         Royal Pari
# 10    18.08.2019  Oriente Petrolero        1    NaN      The Strongest
# 11    18.08.2019        Wilstermann        5    NaN             Aurora
# 12    18.08.2019            Bolivar        1    NaN           San Jose
# 13    18.08.2019        Real Potosi        5    NaN           Blooming
# 14    18.08.2019         Sport Boys        2    NaN            Guabira
# 15    17.08.2019         Royal Pari        0    NaN    Nacional Potosi
# 16    17.08.2019       Always Ready        6    NaN         Destroyers
# 17    15.08.2019  Oriente Petrolero        2    NaN        Real Potosi
# 18    14.08.2019         Royal Pari        1    NaN       Always Ready
# 19    14.08.2019            Guabira        0    NaN            Bolivar
# 20    14.08.2019    Nacional Potosi        5    NaN           Blooming
# 21    11.08.2019           Blooming        2    NaN            Bolivar
# 22    11.08.2019           San Jose        1    NaN        Wilstermann
# 23    11.08.2019             Aurora        2    NaN  Oriente Petrolero
# 24    11.08.2019      The Strongest        4    NaN         Royal Pari
# 25    10.08.2019         Destroyers        1    NaN        Real Potosi
# 26    10.08.2019    Nacional Potosi        1    NaN         Sport Boys
# 27    10.08.2019            Guabira        2    NaN       Always Ready
# 28    08.08.2019  Oriente Petrolero        1    NaN           San Jose
# 29    08.08.2019         Royal Pari        2    NaN             Aurora
# ...          ...                ...      ...    ...                ...
# 5114  27.02.2000           Blooming        2    NaN      Independiente
# 5115  27.02.2000            Bolivar        1    NaN      The Strongest
# 5116  27.02.2000      Central Union        1    NaN        Wilstermann
# 5117  27.02.2000            Guabira        2    NaN  Oriente Petrolero
# 5118  27.02.2000            Pompeya        4    NaN        Real Potosi
# 5119  26.02.2000         Santa Cruz        5    NaN           Mariscal
# 5120  24.02.2000        Wilstermann        2    NaN  Oriente Petrolero
# 5121  20.02.2000      Central Union        0    NaN           Blooming
# 5122  20.02.2000      Independiente        3    NaN            Pompeya
# 5123  20.02.2000  Oriente Petrolero        3    NaN         Santa Cruz
# 5124  20.02.2000        Real Potosi        3    NaN            Bolivar
# 5125  20.02.2000        Wilstermann        3    NaN           Mariscal
# 5126  19.02.2000      The Strongest        4    NaN            Guabira
# 5127  16.02.2000           Blooming        5    NaN           Mariscal
# 5128  16.02.2000            Bolivar        2    NaN            Guabira
# 5129  16.02.2000      Central Union        1    NaN  Oriente Petrolero
# 5130  16.02.2000      Independiente        2    NaN      The Strongest
# 5131  16.02.2000            Pompeya        0    NaN         Santa Cruz
# 5132  16.02.2000        Real Potosi        3    NaN        Wilstermann
# 5133  13.02.2000           Blooming        2    NaN        Wilstermann
# 5134  13.02.2000            Bolivar        1    NaN      Independiente
# 5135  13.02.2000            Guabira        4    NaN        Real Potosi
# 5136  13.02.2000            Pompeya        3    NaN      Central Union
# 5137  12.02.2000           Mariscal        2    NaN  Oriente Petrolero
# 5138  12.02.2000         Santa Cruz        1    NaN      The Strongest
# 5139  06.02.2000      Central Union        0    NaN            Bolivar
# 5140  06.02.2000      Independiente        4    NaN            Guabira
# 5141  06.02.2000        Real Potosi        3    NaN         Santa Cruz
# 5142  06.02.2000      The Strongest        1    NaN           Mariscal
# 5143  05.02.2000           Blooming        1    NaN            Pompeya
#
#       goals_2  par_2            tournament
# 0           4    NaN  Division Profesional
# 1           1    NaN  Division Profesional
# 2           3    NaN  Division Profesional
# 3           3    NaN  Division Profesional
# 4           1    NaN  Division Profesional
# 5           0    NaN  Division Profesional
# 6           1    NaN  Division Profesional
# 7           2    NaN  Division Profesional
# 8           1    NaN  Division Profesional
# 9           0    NaN  Division Profesional
# 10          2    NaN  Division Profesional
# 11          1    NaN  Division Profesional
# 12          4    NaN  Division Profesional
# 13          1    NaN  Division Profesional
# 14          0    NaN  Division Profesional
# 15          2    NaN  Division Profesional
# 16          0    NaN  Division Profesional
# 17          1    NaN  Division Profesional
# 18          1    NaN  Division Profesional
# 19          5    NaN  Division Profesional
# 20          0    NaN  Division Profesional
# 21          3    NaN  Division Profesional
# 22          2    NaN  Division Profesional
# 23          1    NaN  Division Profesional
# 24          0    NaN  Division Profesional
# 25          1    NaN  Division Profesional
# 26          1    NaN  Division Profesional
# 27          0    NaN  Division Profesional
# 28          0    NaN  Division Profesional
# 29          2    NaN  Division Profesional
# ...       ...    ...                   ...
# 5114        0    NaN   Liga de Futbol Prof
# 5115        1    NaN   Liga de Futbol Prof
# 5116        1    NaN   Liga de Futbol Prof
# 5117        2    NaN   Liga de Futbol Prof
# 5118        1    NaN   Liga de Futbol Prof
# 5119        1    NaN   Liga de Futbol Prof
# 5120        0    NaN   Liga de Futbol Prof
# 5121        1    NaN   Liga de Futbol Prof
# 5122        1    NaN   Liga de Futbol Prof
# 5123        0    NaN   Liga de Futbol Prof
# 5124        2    NaN   Liga de Futbol Prof
# 5125        0    NaN   Liga de Futbol Prof
# 5126        0    NaN   Liga de Futbol Prof
# 5127        2    NaN   Liga de Futbol Prof
# 5128        1    NaN   Liga de Futbol Prof
# 5129        1    NaN   Liga de Futbol Prof
# 5130        2    NaN   Liga de Futbol Prof
# 5131        0    NaN   Liga de Futbol Prof
# 5132        1    NaN   Liga de Futbol Prof
# 5133        0    NaN   Liga de Futbol Prof
# 5134        4    NaN   Liga de Futbol Prof
# 5135        0    NaN   Liga de Futbol Prof
# 5136        2    NaN   Liga de Futbol Prof
# 5137        2    NaN   Liga de Futbol Prof
# 5138        2    NaN   Liga de Futbol Prof
# 5139        2    NaN   Liga de Futbol Prof
# 5140        0    NaN   Liga de Futbol Prof
# 5141        0    NaN   Liga de Futbol Prof
# 5142        0    NaN   Liga de Futbol Prof
# 5143        0    NaN   Liga de Futbol Prof
#
# [5144 rows x 8 columns]
